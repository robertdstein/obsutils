# %%
from pathlib import Path
from dotenv import load_dotenv
import os
import pandas as pd
from astropy import units as u
import numpy as np
from obsutils.utils import SkyportalClient
from galsynthspec.skyportal.query import strip_tns_name

# %%
from galsynthspec.paths import data_dir as galsynthspec_data_dir

# %%
uvot_data_dir = Path(os.getenv("UVOT_DATA_DIR"))

# %%
source = "AT2025iuh"
send_to_fritz = True
instrument_id = 29 # UVOT is 46

# %%
uvot_df = pd.read_csv(uvot_data_dir / f"{source}/uvot_summary.csv")
uvot_df
# Out:
#    Unnamed: 0                     ISOT           MJD          RA        DEC  \
# 0           0  2025-05-09T17:29:58.590  60804.729150  175.173875  18.238647
# 1           1  2025-05-09T17:37:51.787  60804.734627  175.173875  18.238647
# 2           2  2025-05-09T17:45:32.168  60804.739956  175.173875  18.238647
# 3           3  2025-06-11T16:43:22.786  60837.696792  175.173875  18.238647
# 4           4  2025-06-11T16:50:31.785  60837.701757  175.173875  18.238647
# 5           5  2025-06-11T16:54:50.209  60837.704748  175.173875  18.238647
# 6           6  2025-06-11T17:01:41.163  60837.709504  175.173875  18.238647
#
#      FILTER   EXPOSURE     AB_MAG  AB_MAG_ERR  AB_MAG_LIM  PARENT_DIR
# 0  UVW2      920.78107  19.483274    0.089635   22.518467    19761001
# 1  UVM2      920.80273  19.156223    0.081994   22.482860    19761001
# 2  UVW1      865.28120  19.234810    0.076888   22.350693    19761001
# 3  UVM2      499.75940  19.408901    0.109979   21.642593    19761002
# 4  UVW1      333.39010  19.365845    0.108612   21.589762    19761002
# 5  U         166.11954  19.456402    0.133981   20.981924    19761002
# 6  UVW2      629.31700  19.615685    0.099921   22.475672    19761002

# %%
gss_df = pd.read_json(galsynthspec_data_dir / f"{source}/synthetic_photometry.json").set_index("band")
gss_df
# Out:
#             predicted_mag    sigma+    sigma-  measured_mag  measured_err  \
# band
# galex_FUV       21.896536  0.292748  0.284521           NaN           NaN
# galex_NUV       21.672154  0.204190  0.233676           NaN           NaN
# uvot_w2         21.820776  0.230559  0.248358           NaN           NaN
# uvot_m2         21.692874  0.208514  0.237640           NaN           NaN
# uvot_w1         21.535498  0.177685  0.208377           NaN           NaN
# sdss_u0         21.044003  0.103820  0.112479     21.148690      0.139324
# sdss_g0         20.046372  0.056830  0.067209     20.115580      0.022473
# sdss_r0         19.275389  0.079840  0.110906     19.390750      0.020527
# sdss_i0         19.100986  0.064149  0.057349     19.049000      0.025018
# sdss_z0         18.847466  0.058703  0.057546     18.760550      0.085761
# twomass_J       18.490952  0.049552  0.056734           NaN           NaN
# twomass_H       18.383519  0.054083  0.050923           NaN           NaN
# twomass_Ks      18.320704  0.068491  0.078866           NaN           NaN
# wise_w1         18.859158  0.064669  0.079937     18.883347      0.065000
# wise_w2         19.174076  0.090335  0.098582     19.075442      0.160000
# wise_w3         16.945193  0.205303  0.263929     16.984352      0.262000
# wise_w4         16.670986  0.215338  0.269100           NaN     15.011302
#
#             extinction  measured_mag_deextincted  predicted_mag_extincted
# band
# galex_FUV     0.158460                       NaN                22.054996
# galex_NUV     0.170105                       NaN                21.842259
# uvot_w2       0.184202                       NaN                22.004978
# uvot_m2       0.181583                       NaN                21.874457
# uvot_w1       0.130447                       NaN                21.665945
# sdss_u0       0.096482                 21.052208                21.140485
# sdss_g0       0.075075                 20.040505                20.121447
# sdss_r0       0.051429                 19.339321                19.326818
# sdss_i0       0.038143                 19.010857                19.139129
# sdss_z0       0.028243                 18.732307                18.875709
# twomass_J     0.016190                       NaN                18.507143
# twomass_H     0.010262                       NaN                18.393781
# twomass_Ks    0.006815                       NaN                18.327519
# wise_w1       0.003929                 18.879418                18.863088
# wise_w2       0.002749                 19.072692                19.176825
# wise_w3       0.000988                 16.983363                16.946181
# wise_w4       0.000545                       NaN                16.671531

# %%
bands = [x.strip().lower() for x in uvot_df["FILTER"]]
uvot_band = [f"sdss_{x}0" if len(x) == 1 else f"uvot_{x[-2:]}" for x in bands]
mask = [x in ['sdss_u0', 'uvot_w1', 'uvot_m2', 'uvot_w2'] for x in uvot_band]
uvot_df["band"] = uvot_band
uvot_df = uvot_df[mask].reset_index(drop=True)
uvot_df
# Out:
#    Unnamed: 0                     ISOT           MJD          RA        DEC  \
# 0           0  2025-05-09T17:29:58.590  60804.729150  175.173875  18.238647
# 1           1  2025-05-09T17:37:51.787  60804.734627  175.173875  18.238647
# 2           2  2025-05-09T17:45:32.168  60804.739956  175.173875  18.238647
# 3           3  2025-06-11T16:43:22.786  60837.696792  175.173875  18.238647
# 4           4  2025-06-11T16:50:31.785  60837.701757  175.173875  18.238647
# 5           5  2025-06-11T16:54:50.209  60837.704748  175.173875  18.238647
# 6           6  2025-06-11T17:01:41.163  60837.709504  175.173875  18.238647
#
#      FILTER   EXPOSURE     AB_MAG  AB_MAG_ERR  AB_MAG_LIM  PARENT_DIR     band
# 0  UVW2      920.78107  19.483274    0.089635   22.518467    19761001  uvot_w2
# 1  UVM2      920.80273  19.156223    0.081994   22.482860    19761001  uvot_m2
# 2  UVW1      865.28120  19.234810    0.076888   22.350693    19761001  uvot_w1
# 3  UVM2      499.75940  19.408901    0.109979   21.642593    19761002  uvot_m2
# 4  UVW1      333.39010  19.365845    0.108612   21.589762    19761002  uvot_w1
# 5  U         166.11954  19.456402    0.133981   20.981924    19761002  sdss_u0
# 6  UVW2      629.31700  19.615685    0.099921   22.475672    19761002  uvot_w2

# %%
hosts_df = pd.DataFrame(gss_df.loc[x] for x in uvot_df["band"]).reset_index(drop=True)
df = pd.concat([uvot_df, hosts_df], axis=1)
df
# Out:
#    Unnamed: 0                     ISOT           MJD          RA        DEC  \
# 0           0  2025-05-09T17:29:58.590  60804.729150  175.173875  18.238647
# 1           1  2025-05-09T17:37:51.787  60804.734627  175.173875  18.238647
# 2           2  2025-05-09T17:45:32.168  60804.739956  175.173875  18.238647
# 3           3  2025-06-11T16:43:22.786  60837.696792  175.173875  18.238647
# 4           4  2025-06-11T16:50:31.785  60837.701757  175.173875  18.238647
# 5           5  2025-06-11T16:54:50.209  60837.704748  175.173875  18.238647
# 6           6  2025-06-11T17:01:41.163  60837.709504  175.173875  18.238647
#
#      FILTER   EXPOSURE     AB_MAG  AB_MAG_ERR  AB_MAG_LIM  PARENT_DIR  \
# 0  UVW2      920.78107  19.483274    0.089635   22.518467    19761001
# 1  UVM2      920.80273  19.156223    0.081994   22.482860    19761001
# 2  UVW1      865.28120  19.234810    0.076888   22.350693    19761001
# 3  UVM2      499.75940  19.408901    0.109979   21.642593    19761002
# 4  UVW1      333.39010  19.365845    0.108612   21.589762    19761002
# 5  U         166.11954  19.456402    0.133981   20.981924    19761002
# 6  UVW2      629.31700  19.615685    0.099921   22.475672    19761002
#
#       band  predicted_mag    sigma+    sigma-  measured_mag  measured_err  \
# 0  uvot_w2      21.820776  0.230559  0.248358           NaN           NaN
# 1  uvot_m2      21.692874  0.208514  0.237640           NaN           NaN
# 2  uvot_w1      21.535498  0.177685  0.208377           NaN           NaN
# 3  uvot_m2      21.692874  0.208514  0.237640           NaN           NaN
# 4  uvot_w1      21.535498  0.177685  0.208377           NaN           NaN
# 5  sdss_u0      21.044003  0.103820  0.112479      21.14869      0.139324
# 6  uvot_w2      21.820776  0.230559  0.248358           NaN           NaN
#
#    extinction  measured_mag_deextincted  predicted_mag_extincted
# 0    0.184202                       NaN                22.004978
# 1    0.181583                       NaN                21.874457
# 2    0.130447                       NaN                21.665945
# 3    0.181583                       NaN                21.874457
# 4    0.130447                       NaN                21.665945
# 5    0.096482                 21.052208                21.140485
# 6    0.184202                       NaN                22.004978

# %%
mags = df["AB_MAG"].to_numpy() * u.ABmag
host_mags = df["predicted_mag_extincted"].to_numpy() * u.ABmag

# %%
subs = (mags.to(u.Jansky) - host_mags.to(u.Jansky)).to(u.ABmag)
subs
# Out:
# <Magnitude [19.59528269, 19.24886934, 19.35713214, 19.52719018,
#             19.50490406, 19.7151072 , 19.74310629] mag(AB)>

# %%
df["sub_mag_deextincted"] = subs.value - df["extinction"]

# %%
sigma_p = ((df["predicted_mag_extincted"].to_numpy() + df["sigma+"].to_numpy()) * u.ABmag).to(u.Jansky)
sigma_p
# Out:
# <Quantity [4.63217449e-06, 5.33103817e-06, 6.64580880e-06, 5.33103817e-06,
#            6.64580880e-06, 1.15419198e-05, 4.63217449e-06] Jy>

# %%
diff = host_mags.to(u.Jansky) - sigma_p
diff
# Out:
# <Quantity [1.09589951e-06, 1.12873452e-06, 1.18167122e-06, 1.12873452e-06,
#            1.18167122e-06, 1.15814379e-06, 1.09589951e-06] Jy>

# %%
diff_uvot = ((df["AB_MAG"].to_numpy() - df["AB_MAG_ERR"].to_numpy()) * u.ABmag).to(u.Jansky) - mags.to(u.Jansky)
diff_uvot
# Out:
# <Quantity [5.02912563e-06, 6.19539201e-06, 5.39114687e-06, 6.67124923e-06,
#            6.85042259e-06, 7.86738186e-06, 4.98651660e-06] Jy>

# %%
unc = (diff_uvot ** 2. + diff**2.)**0.5
unc
# Out:
# <Quantity [5.14714487e-06, 6.29737435e-06, 5.51913141e-06, 6.76606296e-06,
#            6.95159237e-06, 7.95216916e-06, 5.10552089e-06] Jy>

# %%
err = (subs.to(u.ABmag) - (subs.to(u.Jansky) + unc).to(u.ABmag)).value

# %%
# df["sigma"] = 0.5 * (df["sigma+"] + df["sigma-"])
df["error"] = err

# %%
df[["ISOT", "FILTER", "AB_MAG", "AB_MAG_ERR", "sub_mag_deextincted", "error"]]
# Out:
#                       ISOT    FILTER     AB_MAG  AB_MAG_ERR  \
# 0  2025-05-09T17:29:58.590  UVW2      19.483274    0.089635
# 1  2025-05-09T17:37:51.787  UVM2      19.156223    0.081994
# 2  2025-05-09T17:45:32.168  UVW1      19.234810    0.076888
# 3  2025-06-11T16:43:22.786  UVM2      19.408901    0.109979
# 4  2025-06-11T16:50:31.785  UVW1      19.365845    0.108612
# 5  2025-06-11T16:54:50.209  U         19.456402    0.133981
# 6  2025-06-11T17:01:41.163  UVW2      19.615685    0.099921
#
#    sub_mag_deextincted     error
# 0            19.411080  0.101161
# 1            19.067287  0.090412
# 2            19.226685  0.087659
# 3            19.345607  0.123590
# 4            19.374457  0.124355
# 5            19.618625  0.169046
# 6            19.558904  0.114275

# %%
ztf_name = source if source[:3] == "ZTF" else None
print(ztf_name)
# Out:
# None

# %%
client = SkyportalClient()
client.set_up_session()

# %%
def get_ztf_name(source):
    res = client.api(
        "GET", 
        f"sources/{strip_tns_name(source)}",
    )
    res.raise_for_status()
    ztf_name = [x["obj_id"] for x in res.json()["data"]["duplicates"] if x["obj_id"][:3] == "ZTF"][0]
    return ztf_name

# %%
# print(matches)

# %%
ORIGIN = "uvotredux/galsynthspec"

if send_to_fritz:

    payload = {
        "mjd": df["MJD"].to_list(),
        "filter": [f"uvot::{x.lower().strip()}" for x in df["FILTER"]],
        "obj_id": get_ztf_name(source),
        "instrument_id": instrument_id,
        "ra": df["RA"].to_list(),
        "dec": df["DEC"].to_list(),
        "ra_unc": None,
        "dec_unc": None,
        "origin": ORIGIN,
        "group_ids": [1],
        "magsys": "ab",
        "mag": df["sub_mag_deextincted"].to_list(),
        "magerr": df["error"].to_list(),
        "limiting_mag": df["AB_MAG_LIM"].to_list(),
        "limiting_mag_nsigma": 3,
    }
    print(payload)
    res = client.api(
        "PUT", 
        "photometry",
        data=payload
    )
    print(res.json())
    res.raise_for_status()
# Out:
# {'mjd': [60804.72915034919, 60804.73462715891, 60804.73995565, 60837.69679150903, 60837.701756768285, 60837.70474778704, 60837.7095042], 'filter': ['uvot::uvw2', 'uvot::uvm2', 'uvot::uvw1', 'uvot::uvm2', 'uvot::uvw1', 'uvot::u', 'uvot::uvw2'], 'obj_id': 'ZTF25aaooewz', 'instrument_id': 29, 'ra': [175.173875, 175.173875, 175.173875, 175.173875, 175.173875, 175.173875, 175.173875], 'dec': [18.2386472222222, 18.2386472222222, 18.2386472222222, 18.2386472222222, 18.2386472222222, 18.2386472222222, 18.2386472222222], 'ra_unc': None, 'dec_unc': None, 'origin': 'uvotredux/galsynthspec', 'group_ids': [1], 'magsys': 'ab', 'mag': [19.411080471501307, 19.06728662141176, 19.22668547215289, 19.345607460673925, 19.374457400653753, 19.618625123715766, 19.558904072544383], 'magerr': [0.10116130991627514, 0.09041152414489417, 0.08765931951990069, 0.12359017422935636, 0.12435463043188122, 0.1690460476066491, 0.11427505530151194], 'limiting_mag': [22.518467, 22.48286, 22.350693, 21.642593, 21.589762, 20.981924, 22.475672], 'limiting_mag_nsigma': 3}
# {'status': 'success', 'data': {'ids': [705052932, 705052933, 705052934, 705052935, 705052936, 705052937, 705052938]}, 'version': '1.4.0+fritz.61df14b'}
